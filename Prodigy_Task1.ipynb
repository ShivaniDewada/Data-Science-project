# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaniDewada/Data-Science-project/blob/main/Prodigy_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
from pandas import DataFrame
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/DATA'
datafile = 'hrdata.csv'
filename = DIR+'/'+datafile

# %%
os.chdir(DIR)
# !ls
# Out:
#  cereal.csv  'IMDB Top 250 Movies.csv'	 MMix.csv	     socialmedia.csv
#  hrdata.csv   iris.csv			 sciencenmaths.csv   train.csv

# %%
df=pd.read_csv(filename)
df
# Out:
#       EmployeeCount  EmployeeID              Department  \
# 0                 1           1                   Sales
# 1                 1           2  Research & Development
# 2                 1           4  Research & Development
# 3                 1           5  Research & Development
# 4                 1           7  Research & Development
# ...             ...         ...                     ...
# 1465              1        2061  Research & Development
# 1466              1        2062  Research & Development
# 1467              1        2064  Research & Development
# 1468              1        2065                   Sales
# 1469              1        2068  Research & Development
#
#                         JobRole Attrition  Gender  Age MaritalStatus  \
# 0               Sales Executive       Yes  Female   41        Single
# 1            Research Scientist        No    Male   49       Married
# 2         Laboratory Technician       Yes    Male   37        Single
# ...

# %%
df.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
Age = df['Age']
Income = df['Income']

plt.bar(Age, Income, color='skyblue')
# Out:
# <BarContainer object of 1470 artists>
